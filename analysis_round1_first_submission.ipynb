# %%
import pandas as pd
import numpy as np

df = pd.read_csv('log_data_r1.csv', sep=';')

df
# Out:
#                                                                                                                                                                                                979fe29a-dbcc-4a5c-a3b2-05e0de74ebb7
# day timestamp product          bid_price_1 bid_volume_1 bid_price_2 bid_volume_2 bid_price_3 bid_volume_3 ask_price_1 ask_volume_1 ask_price_2 ask_volume_2 ask_price_3 ask_volume_3 mid_price                      profit_and_loss
# 1   0         SQUID_INK        1834        23           NaN         NaN          NaN         NaN          1838        23           NaN         NaN          NaN         NaN          1836.0                                     0.0
#               RAINFOREST_RESIN 9998        9            9995        23           NaN         NaN          10005       23           NaN         NaN          NaN         NaN          10001.5                                    0.0
# ...

# %%
import pandas as pd

# Load the file again but skip the first row if it's not the header
df = pd.read_csv('log_data_r1.csv', sep=';', header=1)

df
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       1          0         SQUID_INK         1834            23
# 1       1          0  RAINFOREST_RESIN         9998             9
# 2       1          0              KELP         2032            23
# 3       1        100              KELP         2034             1
# 4       1        100         SQUID_INK         1837             1
# ...   ...        ...               ...          ...           ...
# 2995    1      99800         SQUID_INK         1814            26
# 2996    1      99800  RAINFOREST_RESIN         9996             1
# 2997    1      99900         SQUID_INK         1816            27
# 2998    1      99900  RAINFOREST_RESIN         9998             6
# 2999    1      99900              KELP         2034            27
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0             NaN           NaN          NaN           NaN         1838
# ...

# %%
# Clean column names just in case
df.columns = df.columns.str.strip()

# Convert profit column to numeric
df['profit_and_loss'] = pd.to_numeric(df['profit_and_loss'], errors='coerce')

# Group and sum PnL by product
pnl_by_product = df.groupby('product')['profit_and_loss'].sum().sort_values(ascending=False)

# Show the result
print(pnl_by_product)
# Out:
# product
# RAINFOREST_RESIN    919493.000000
# KELP                 96168.653076
# SQUID_INK                0.000000
# Name: profit_and_loss, dtype: float64
